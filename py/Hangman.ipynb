# %%
import os
word=input()
letters=[]
for l in word:
    letters.append(l)


spaces=len(letters)*"_ "
mew=spaces.split()


if " " in letters:
    for l in range(len(mew)):
        if letters[l]==" ":
            mew[l]=" "
print(*mew,sep="")            



hangman=["O","/","|","\\","/","\\"]
guy={0:" ", 1:" ", 2:" ", 3:" ", 4:" ", 5:" "}




ul=[]
mistake=0
letter=0
os.system("cls")
for p,b in zip(hangman,range(6)):
    mistake=False
    while mistake==False:
        print("used letters: "+str(ul))
        letter=input()
        while letter in ul:
            letter=input("this letter has already been entered, please use another one")
        if letter in letters:
            for l in range(len(letters)):
                if letter==letters[l]:
                    mew[l]=letter
                    print(*mew,sep="")
        else:
            mistake=True
        ul.append(letter)
        if mew==letters:
            break
    if mew==letters:
        break
    guy[b]=p
    print("""
  +---+
  |   |
  # %s   |
 # %s%s%s  |
 # %s %s  |
      |
------+
""" %(guy[0],guy[1],guy[2],guy[3],guy[4],guy[5]))

if mew==letters:
    print("haha congrats")
else:
    print("boo loser \n Word was: ", word)
